# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://vnexpress.net/thoi-su'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
def get_article(article_div):
    title = article_div.find(class_ = "title-news")
    link = ''
    ti = ''
    if title is not None:
        ti = title.text.strip()
        link = title.a['href']
    des = ''
    description = article_div.find('p', 'description')
    if description != None:
      des = description.text.strip()
    dt = ''
    date = article_div.find('span', 'time-public')
    if date != None:
      dt = date.text.strip()

    return {'Title': ti, 'Description': des, 'Publish_Time': dt, 'Link': link}

# %%
### Run your tests here
article_divs = soup.find_all('article')
data = [] 

print(len(article_divs))

for article_div in article_divs:
    row = get_article(article_div)
    data.append(row)
df = pd.DataFrame(data, columns = ['Title', 'Description', 'Publish_Time', 'Link'])
df.head(35)
# Out:
# 41
#                                                 Title  \
# 0   Hòa Bình rà soát dự án lắp dựng khẩu hiệu gần ...
# 1         Giảm thủ tục nhận gói hỗ trợ 62.000 tỷ đồng
# 2                           Bán hơn 15.000 vé tàu Tết
# 3   Ông Mai Tiến Dũng: 'Văn bản chồng chất không n...
# 4   Ý kiến trái chiều về vị trí sân bay thứ hai ở ...
# 5
# 6        Vì sao TP HCM phải sớm thành lập TP Thủ Đức?
# 7      Chưa xác định được niên đại bãi cọc Đầm Thượng
# 8                 Sài Gòn có thể mưa to trong 10 ngày
# 9    Thông xe kỹ thuật tuyến đường ven biển Quảng Nam
# 10     Ra mắt các nền tảng công nghệ kết nối tri thức
# 11      Những thách thức miền Tây đối mặt khi lũ thấp
# 12
# 13   Thứ trưởng Xây dựng xin lỗi người dân Quảng Bình
# 14         Chính sách nổi bật có hiệu lực từ tháng 10
# 15        Ôtô cháy rụi sau khi tông đuôi xe container
# 16                                   Cháy bãi giữ ôtô
# 17         Đàn bò tót đói trơ xương sắp được bàn giao
# 18       Phụ huynh 'đau đầu' với sách giáo khoa lớp 1
# 19
# 20  Cục CSGT lý giải đề xuất tiếp nhận quản lý đào...
# 21  Vì sao cảnh sát bụng to sẽ không được làm nhiệ...
# 22         Cấm xe qua cầu Nguyễn Hữu Cảnh gần 6 tháng
# 23      Quân đội tiếp tục điều chỉnh tổ chức biên chế
# 24                          Xe đầu kéo tông hai người
# 25                    Đồng Tháp Mười những năm lũ lớn
# 26
# 27            Giao thông TP HCM 'bức bí' vì thiếu vốn
# 28         5 người đu dây thoát khỏi căn nhà bốc cháy
# 29             Căng lưới cao 10 m ngăn voọc cắn người
# 30                  Khởi công 3 dự án cao tốc Bắc Nam
# 31                  Hơn 3 năm chưa xây xong cầu 200 m
# 32       Ba nguyên lãnh đạo sở ở Khánh Hòa bị kỷ luật
# 33
# 34            Thu hồi tiền hỗ trợ Covid-19 đã chi sai
#
#                                           Description Publish_Time  \
# 0   Thường trực Tỉnh ủy Hòa Bình yêu cầu xem xét g...     2h trước
# 1
# 2
# 3
# 4   Trong khi nhiều chuyên gia ủng hộ đề xuất xây ...
# 5
# 6   Phó bí thư Thường trực TP HCM cho biết, nếu kh...
# 7   Hải PhòngGiám định niên đại mẫu cọc Đầm Thượng...
# 8   Ảnh hưởng của rãnh áp thấp có trục đi ngang Na...
# 9   Sáng 1/10, tuyến đường hơn 1.470 tỷ đồng đi qu...
# 10  Các nền tảng công nghệ hỗ trợ kết nối thông ti...
# 11  Thạc sĩ Nguyễn Hữu Thiện, chuyên gia nghiên cứ...
# 12
# 13  Thứ trưởng Xây dựng Nguyễn Đình Toàn gửi lời x...
